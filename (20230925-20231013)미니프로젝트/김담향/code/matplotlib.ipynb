# %%
# import numpy as np
# import pandas as pd

# from urllib.request import urlopen
# from bs4 import BeautifulSoup as bs

# import warnings
# warnings.filterwarnings(action='ignore')

# import matplotlib.pyplot as plt

# plt.rcParams['font.family'] = 'Gulim'

# %%
# pandas패키지 사용하기
import pandas as pd

# matplotlib패키지 사용하기
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Gulim'   #한글글씨를 인지할 수 있도록 글씨체 지정

# numpy패키지 사용하기
import numpy as np

# %%
# csv파일 불러오기
df_c = pd.read_csv('df_final.csv')
df_e = pd.read_csv('sale_by_month_covid_th.csv')

# %%
# dataframe[df]의 컬럼명 확인
df_c.columns
df_e.columns
# Out:
# Index(['Year', 'Month', '지역', 'local_id', '가정용', '업무용', '산업용'], dtype='object')

# %%
# column[year]과 column[month]를 합쳐서 column[year_month]를 만들기
df_c['year_month'] = df_c['year'].astype(str) + df_c['month'].astype(str)

#년월에 따른 연령별 확진자수에 대한 선그래프
fig, ax = plt.subplots(figsize=(50,4))
ax.plot(df_c['year_month'], df_c['0-9(confirmed_case)'], label = '0-9')
ax.plot(df_c['year_month'], df_c['10-19(confirmed_case)'], label = '10-19')
ax.plot(df_c['year_month'], df_c['20-29(confirmed_case)'], label = '20-29')
ax.plot(df_c['year_month'], df_c['30-39(confirmed_case)'], label = '30-39')
ax.plot(df_c['year_month'], df_c['40-49(confirmed_case)'], label = '40-49')
ax.plot(df_c['year_month'], df_c['50-59(confirmed_case)'], label = '50-59')
ax.plot(df_c['year_month'], df_c['60-69(confirmed_case)'], label = '60-69')
ax.plot(df_c['year_month'], df_c['70-79(confirmed_case)'], label = '70-79')
ax.plot(df_c['year_month'], df_c['over80(confirmed_case)'], label = 'over80')
ax.legend()
fig.show()

#년월에 따른 연령별 확진률에 대한 선그래프
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(df_c['year_month'], df_c['0-9(rate)'], label = '0-9')
ax.plot(df_c['year_month'], df_c['10-19(rate)'], label = '10-19')
ax.plot(df_c['year_month'], df_c['20-29(rate)'], label = '20-29')
ax.plot(df_c['year_month'], df_c['30-39(rate)'], label = '30-39')
ax.plot(df_c['year_month'], df_c['40-49(rate)'], label = '40-49')
ax.plot(df_c['year_month'], df_c['50-59(rate)'], label = '50-59')
ax.plot(df_c['year_month'], df_c['60-69(rate)'], label = '60-69')
ax.plot(df_c['year_month'], df_c['70-79(rate)'], label = '70-79')
ax.plot(df_c['year_month'], df_c['over80(rate)'], label = 'over80')
ax.legend()
fig.show()

fig, ax = plt.subplots(figsize=(10,4))
ax.plot(df_e_tmp3['year_month'], df_e_tmp3['가정용'], label = '가정용')
ax.plot(df_e_tmp3['year_month'], df_e_tmp3['산업용'], label = '산업용')
ax.plot(df_e_tmp3['year_month'], df_e_tmp3['업무용'], label = '업무용')


ax.legend()
fig.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_31944\3283262615.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\AppData\Local\Temp\ipykernel_31944\3283262615.py:30: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\user\AppData\Local\Temp\ipykernel_31944\3283262615.py:39: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df_e.columns
# Out:
# Index(['Year', 'Month', '지역', 'local_id', '가정용', '업무용', '산업용'], dtype='object')

# %%
# column[year]과 column[month]를 합쳐서 column[year_month]를 만들기
df_e['year_month'] = df_e['Year'].astype(str) + df_e['Month'].astype(str)

# %%
df_e.dtypes
# Out:
# Year           int64
# Month          int64
# 지역            object
# local_id       int64
# 가정용            int64
# 업무용            int64
# 산업용            int64
# year_month    object
# dtype: object

# %%
tmp = df_e['year_month']
df_e_tmp1 = df_e.groupby(tmp).sum()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_31944\1763395452.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_e_tmp1 = df_e.groupby(tmp).sum()

# %%
tmp = df_e['year_month'].drop_duplicates().to_list()

df_e_tmp2 = df_e_tmp1.reindex(tmp)

# %%
df_e_tmp3 = df_e_tmp2.reset_index()

# %%
#년월에 따른 연령별 확진자수에 대한 선그래프
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(df_e_tmp3['year_month'], df_e_tmp3['가정용'], label = '가정용')
ax.legend()
fig.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_31944\212832511.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
